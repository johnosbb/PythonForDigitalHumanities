# %%
filename = "./ReferenceFiles/alice.txt"
with open(filename,"r") as f:
    data  = f.read() # read as a stream
    #print(data)SS
    #data = f.readlines() # read as a list of lines
    #print(data[0])
    chapters = data.split("CHAPTER") # split into chapters
    print(chapters[2]) # print a specific chapter
# Out:
#  II
#
#                         The Pool of Tears
#
#
#   `Curiouser and curiouser!' cried Alice (she was so much
# surprised, that for the moment she quite forgot how to speak good
# English); `now I'm opening out like the largest telescope that
# ever was!  Good-bye, feet!' (for when she looked down at her
# feet, they seemed to be almost out of sight, they were getting so
# far off).  `Oh, my poor little feet, I wonder who will put on
# your shoes and stockings for you now, dears?  I'm sure _I_ shan't
# be able!  I shall be a great deal too far off to trouble myself
# about you:  you must manage the best way you can; --but I must be
# kind to them,' thought Alice, `or perhaps they won't walk the
# way I want to go!  Let me see:  I'll give them a new pair of
# boots every Christmas.'
#
#   And she went on planning to herself how she would manage it.
# `They must go by the carrier,' she thought; `and how funny it'll
# seem, sending presents to one's own feet!  And how odd the
# ...

# %%
filename = "./ReferenceFiles/alice.txt"
with open(filename,"r") as f:
    data  = f.read() # read as a stream
    #print(data)SS
    #data = f.readlines() # read as a list of lines
    #print(data[0])
    chapters = data.split("CHAPTER") # split into chapters
    #print(chapters[2]) # print a specific chapter
    
filename2 = "./ReferenceFiles/chapter1.txt"
with open(filename2,"w") as f:
    f.write(chapters[1])

# %%
filename = "./ReferenceFiles/alice.txt"
with open(filename,"r") as f:
    data  = f.read() # read as a stream
    #print(data)SS
    #data = f.readlines() # read as a list of lines
    #print(data[0])
    chapters = data.split("CHAPTER") # split into chapters
    #print(chapters[2]) # print a specific chapter
i = 1    
for chapter in chapters[1:]:    
    if( i < 10):
        chapter_num = f"0{i}"
    else:
        chapter_num = i    
    filename2 = f"./ReferenceFiles/chapter_{chapter_num}.txt"
    with open(filename2,"w") as f:
        f.write(chapters[i])
        i = i+1
